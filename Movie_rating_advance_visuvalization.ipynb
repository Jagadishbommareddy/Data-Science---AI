# %%
import pandas as pd

# %%
movies = pd.read_csv('Movie-Rating.csv')
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %% [markdown]
# # describe
# - describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame.

# %%
movies.describe() 
# if you look at the year the data type is int but when you look at the mean value it showing 2009 which is meaningless
# we have to change to categroy type 
# also from object datatype we will convert to category datatypes
#
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %% [markdown]
# # astype()
# change atrribute to one data type to another data type

# %%
movies['Film'] = movies['Film'].astype('category') # chnage Film attribute from object to category

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies[['Genre','Year']] = movies[['Genre','Year']].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies['Year'] # is it real no. year you can take average,min,max but out come have no meaning
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# # Visuvalization

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # jointplot
# - jointplot is under seaborn feature
# - basically joint plot is a scatter plot
# - if you observe below it find the relation b/w audiene & critics
# - also if you look up you can find the uniform distribution (critics)and normal distriution (audience)
# - joinplot show in all these formats"scatter" | "kde" | "hist" | "hex" | "reg" | "resid"
# - By default joinplot as scatter format

# %% [markdown]
# # If Audiance Rating is More graph look like below

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating')

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating',kind='scatter')

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating',kind='kde')

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating',kind='hist')

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating',kind='reg')

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating',kind='resid')

# %% [markdown]
# # If CriticRating is more graph look like below

# %%
movies.columns = ['Film', 'Genre','AudienceRating','CriticRating','BudgetMillions','Year']

# %%
movies
# Out:
#                       Film      Genre  AudienceRating  CriticRating  \
# 0    (500) Days of Summer      Comedy              87            81
# 1              10,000 B.C.  Adventure               9            44
# 2               12 Rounds      Action              30            52
# 3                127 Hours  Adventure              93            84
# 4                17 Again      Comedy              55            70
# ..                     ...        ...             ...           ...
# 554          Your Highness     Comedy              26            36
# 555        Youth in Revolt     Comedy              68            52
# 556                 Zodiac   Thriller              89            73
# 557            Zombieland      Action              90            87
# 558              Zookeeper     Comedy              14            42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
j = sns.jointplot(data=movies,x='CriticRating', y='AudienceRating')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %% [markdown]
# # distplot
# - seaborn.distplot() function is used to plot the distplot. The distplot represents the univariate distribution of data i.e. data distribution of a variable against the density distribution.

# %%
m1=sns.distplot(movies.AudienceRating)

# %%
m1=sns.distplot(movies.CriticRating)

# %% [markdown]
# sns.set_style || darkgrid, whitegrid, dark, white, ticks

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
m2 = sns.distplot(movies.AudienceRating, bins = 20)

# %% [markdown]
# # plt.hist
# It is a matplotlib feature

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions, \
          movies[movies.Genre == 'Thriller'].BudgetMillions, \
          movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
#if you have 100 categories you canot copy & paste all the things
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
vis1 = sns.lmplot(data=movies,x='CriticRating',y='AudienceRating')

# %%
vis1 = sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg=False)

# %%
vis1 = sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg=False,hue='Genre')

# %% [markdown]
# # aspect
# aspect : (optional) This parameter is Aspect ratio of each facet, so that aspect * height gives the width of each facet in inches.

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre',aspect=1)

# %% [markdown]
# # kernel density estimate (KDE)
# - A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram.
# - KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating)
# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
#change the color with cmap attributes
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shde=True,shade_lowest=False,cmap='Reds')

# %%
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shde=True,shade_lowest=True,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating)

# %%
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating)

# %% [markdown]
# # Subplots
# With the subplot() function you can draw multiple plots in one figure

# %%
f,ax = plt.subplots(1,2,figsize=(12,6))

# %%
f,axes = plt.subplots(1,2,figsize=(12,6))
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0])
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[1])
#axes=[0] refers to 1st subplot
#axes=[1] refers to 2nd subplot

# %%
f,axes = plt.subplots(1,2,figsize=(12,6))
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[1])
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[0])

# %%
f,axes = plt.subplots(1,2,figsize=(12,6))
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[2])
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[0])
# here we have 2 sub plot indexs 0,1 but we are tryting give axes[2] so it raise index out exception
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[144], line 2
#       1 f,axes = plt.subplots(1,2,figsize=(12,6))
# ----> 2 k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[2])
#       3 k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[0])
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
axes

# %% [markdown]
# # Box Plots

# %%
w=sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %% [markdown]
# # Vilon Plot

# %%
v = sns.violinplot(data=movies,x='Genre',y='CriticRating')

# %%
w1 = sns.boxplot(data=movies[movies.Genre=='Drama'],x = 'Year',y='CriticRating')

# %% [markdown]
# # seaborn.FacetGrid()
# - FacetGrid class helps in visualizing distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.
# - A FacetGrid can be drawn with up to three dimensions ? row, col, and hue. The first two have obvious correspondence with the resulting array of axes; think of the hue variable as a third dimension along a depth axis, where different levels are plotted with different colors.
# - FacetGrid object takes a dataframe as input and the names of the variables that will form the row, column, or hue dimensions of the grid. The variables should be categorical and the data at each level of the variable will be used for a facet along that axis.

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(x= movies.CriticRating,y=movies.AudienceRating)

# %% [markdown]
# # Map Scatterplots plots in FaceGrid

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillions')#scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5)
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

# k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating,cmap='Reds',ax = axes[1,1])

# plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'}) #given style
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,shade = True, shade_lowest=True,cmap = 'inferno',ax = axes[0,0])
k1b = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating,cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,shade=True, shade_lowest=True, cmap='inferno',ax = axes[0,1])
k2b = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])

k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating,cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
